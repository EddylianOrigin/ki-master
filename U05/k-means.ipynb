# %% [markdown]
# # 5. Übungsblatt: k-Means-Algorithmus
# In diesem Notebook werden den k-Means-Algorithmus implementieren.
#
# ## 1. Daten einlesen (ToDo)
# Lesen Sie zunächst die Datei `data_3.csv` ein

# %%
import os
import sys
import numpy as np
import matplotlib.pyplot as plt

path = os.getcwd() + os.sep + "data_6.csv"
data = np.loadtxt(path)

# %% [markdown]
# ## 2. Distanz-Metrik definieren (ToDo)
# Um im k-Means Algorithmus die Distanz zwischen zwei Punkten $p, q \in \mathbb{R}^d$ berechnen können, verwenden wir die quadrierte Euklidische Distanz. Diese ist gegeben durch:
# $$
# \parallel p - q \parallel_2^2 = \sum\limits_{r=1}^{d}(p_r - q_r)^2
# $$

# %%
def distance_measuring(data_point, cluster_center):
    # ToDo
    pass

import numpy as np

def softmax(x):
    """Compute softmax values for each sets of scores in x."""
    e_x = np.exp(x - np.max(x))
    return e_x / e_x.sum(axis=0)

scores = [18,20,19]
print(softmax(scores))
# Out:
# [0.09003057 0.66524096 0.24472847]

# %% [markdown]
# ## 3. k-Means-Algorithums implementieren (ToDo)
# Implementieren Sie den k-Means-Algorithmus. Die Rückgabe soll folgende Informationen enthalten:
# 1. eine Liste oder ein Array, das für jeden Datenpunkt die Cluster-ID speichert,
# 2. die Position der Cluster-Mittelpunkte.

# %%
def k_means_shorter(data, k):
    # ToDo

# %% [markdown]
# ## 4. Visualisieren der Ergebnisse (ToDo)
# Schreiben Sie eine Prozedur, die Ihre Ergebnisse visualisiert.

# %%
def plot_data_both_with_list_of_lists(data, list_of_lists, computed_cluster_centers):
    # ToDo

# %% [markdown]
# ## 5. Ausführen der Methoden
# Wenden Sie nun den k-Means-Algorithmus auf die Daten in `data_3.csv` und `data_6.csv` jeweils 20 Mal an, **ohne Seeds zu setzen**. Notieren Sie sich, wie oft die Ergebnisse Ihrer Meinung nach richtig und wie oft sie falsch zugeordnet wurden. Für die Datei `data_3.csv` können Sie von einem `k=3` ausgehen, bei der Datei `data_6.csv` können Sie `k=6` verwenden.

# %%
# ToDo
